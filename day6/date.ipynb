# %%
#handeling date in the python
import datetime

# %%
x=(datetime.datetime.now())

# %%
print(x)
print(x.min)
print(x.hour)
print(x.strftime("%A"))
# Out:
# 2025-08-12 12:29:35.733510
# <built-in method date of datetime.datetime object at 0x00000255525392C0>
# 0001-01-01 00:00:00
# 12
# Tuesday

# %% [markdown]
# ![image.png](attachment:image.png)
